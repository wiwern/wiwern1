# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from xml.dom import minidom
import re
import json

# %matplotlib inline

# %%
wal=open('trends_wal.json', 'r')

# %%
wal
# Out:
# <_io.TextIOWrapper name='trends_wal.json' mode='r' encoding='UTF-8'>

# %%
walm=json.load(wal)

# %%
pd.DataFrame(walm['items'])
# Out:
#                                          addToCartUrl  \
# 0   http://c.affil.walmart.com/t/api01?l=http%3A%2...
# 1   http://c.affil.walmart.com/t/api01?l=http%3A%2...
# 2   http://c.affil.walmart.com/t/api01?l=http%3A%2...
# 3   http://c.affil.walmart.com/t/api01?l=http%3A%2...
# 4   http://c.affil.walmart.com/t/api01?l=http%3A%2...
# 5   http://c.affil.walmart.com/t/api01?l=http%3A%2...
# 6   http://c.affil.walmart.com/t/api01?l=http%3A%2...
# 7   http://c.affil.walmart.com/t/api01?l=http%3A%2...
# 8   http://c.affil.walmart.com/t/api01?l=http%3A%2...
# 9   http://c.affil.walmart.com/t/api01?l=http%3A%2...
# 10  http://c.affil.walmart.com/t/api01?l=http%3A%2...
# 11  http://c.affil.walmart.com/t/api01?l=http%3A%2...
# 12  http://c.affil.walmart.com/t/api01?l=http%3A%2...
# 13  http://c.affil.walmart.com/t/api01?l=http%3A%2...
# 14  http://c.affil.walmart.com/t/api01?l=http%3A%2...
# 15  http://c.affil.walmart.com/t/api01?l=http%3A%2...
# ...
